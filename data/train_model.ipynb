# %% [markdown]
# ## Information
# This notebook is used to fine-tune a pre-trained GPT-2 model on the data that is contained in the data.tsv file from the *data-collection.ipynb* script.
# In the first half of the notebook, all the necessary processing methods are introduced. In the second half, you can choose which plays you want to use for training.
#
# <b> Note </b>: The training is only feasible if you do it on your GPU / on Colab

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %% [markdown]
# ## Processing the data

# %%
import pandas as pd

# Fetching the dialogue lines as a pandas dataframe
dialogue_data = pd.read_table("data.tsv")

# Removing redundant whitespace from the text data
cleaned_text = []
for i in range(len(dialogue_data)):
    text = str(dialogue_data.iloc[i]["text"])
    cleaned_text.append(" ".join(text.split()))

cleaned_text_column = pd.DataFrame({'text': cleaned_text})

dialogue_data.update(cleaned_text_column)

# %%
def get_lines_for_play_id(play_id=0, feature="character_gender"):
    '''
    :param play_id: The play_id of the play of which we want the dialogue lines
    :param feature: The feature that is placed in front of each dialogue line (e.g. character_name, character_gender)
    :return: List with all the lines of play with play_id in the following format: "<s>{feature}: {text}"
    '''
    line_list = []
    dialogues_play_id = dialogue_data[dialogue_data['play_id'] == play_id][[feature, "text"]]
    for row in dialogues_play_id.itertuples():
        line = "<s>" + str(row[1]) + ": " + row[2]
        line_list.append(line)
    return line_list

# %%
from transformers import AutoTokenizer
# We need the tokenizer in the next method
tokenizer = AutoTokenizer.from_pretrained("dbmdz/german-gpt2")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
import math

def input_to_chunks(play_id, feature="character_gender"):
    i = 0

    final_ids = []
    final_mask = []

    new_lines = get_lines_for_play_id(play_id, feature)
    # Iterate over the whole list of lines
    while i < (len(new_lines)-1):
        print(f"i: {i}") ##
        ids_i = []
        mask_i = []
        # Iterate from current i up to (potentially) the end of the lines
        for j in range(i, len(new_lines)):
            # Fetch the input_ids and the mask values for line j
            ids_j, mask_j = tokenizer(new_lines[j]).values()

            # Only append ids of line j if the resulting training example is less than 1024 or 512 tokens long
            if len(ids_i) + len(ids_j) <= 512:
                ids_i += ids_j
                mask_i += mask_j
                # If j is the last line, we want to break out of the j loop and also the i loop (by setting i=j) since we reached the end of our lines
                if j == (len(new_lines)-1):
                    i=j
                    print("j == len(list) (vor else)")

                    # Append the ids and mask to the final list
                    final_ids.append([ids_i])
                    final_mask.append([mask_i])
                    break

            else:
                # I think the part before the next else is unnecessary.
                # (If j is the last line, we want to break out of the j loop and also the i loop (by setting i=j) since we reached the end of our lines)
                if j == (len(new_lines)-1):
                    i = j
                    print("j == len(list)") ##
                    break
                else:
                    # Otherwise, we want to move our new i ca. (j-i / 2) lines
                    print("----")
                    print(f"Länge zum Ende von Zeitpunkt i = {i}: {len(ids_i)}")
                    print(f"i inkrementieren: {i} -> {i + math.floor(3*(j-i)/4) + 1} \t j: {j}, floor term:{math.floor(3*(j-i)/4)}") ##
                    i = i + math.floor(3*(j-i)/4) + 1

                    # Append the ids and mask to the final list
                    final_ids.append([ids_i])
                    final_mask.append([mask_i])

                    break
    return final_ids, final_mask

# %%
# Testing out the methods:

# input_ids, input_mask = input_to_chunks(play_id=187)
#
# print("----------------")
# for i in range(len(input_ids)):
#     print(f"i: {i}\t length: {len(input_ids[i][0])}")
#     print(input_ids[i][0][:10])
#     print(input_mask[i][0][:10])
#     print(tokenizer.decode(input_ids[i][0]), "\n")

# %%
from datasets import Dataset

def get_datasets(train_play_ids, test_play_ids):
    '''
    :param train_play_ids: A list of the play_ids on which the model should be trained
    :param test_play_ids: A list of the play_ids on which the model should be validated
    :return: Two datasets, one for training and one for validating
    '''

    training_dict = {
        'input_ids': [],
        'attention_mask': []
    }

    test_dict = {
        'input_ids': [],
        'attention_mask': []
    }

    for id in train_play_ids:
        input_ids, input_mask = input_to_chunks(play_id=id)
        for i in range(len(input_ids)):
            training_dict["input_ids"].append(input_ids[i][0])
            training_dict["attention_mask"].append(input_mask[i][0])

    for id in test_play_ids:
        input_ids, input_mask = input_to_chunks(play_id=id)
        for i in range(len(input_ids)):
            test_dict["input_ids"].append(input_ids[i][0])
            test_dict["attention_mask"].append(input_mask[i][0])

    train_dataset = Dataset.from_dict(training_dict)
    test_dataset = Dataset.from_dict(test_dict)
    return train_dataset, test_dataset

# %% [markdown]
# ## Training:

# %%
# The plays we want to use during training
dataset_train, dataset_test = get_datasets([0, 1, 2, 3, 4, 5, 6], [7])

# Checking what our datasets look like
print("\n\n-----------Datasets-------------")
print(dataset_train)
print(dataset_test)
# Out:
# i: 0
# ----
# Länge zum Ende von Zeitpunkt i = 0: 498
# i inkrementieren: 0 -> 7 	 j: 9, floor term:6
# i: 7
# ----
# Länge zum Ende von Zeitpunkt i = 7: 486
# i inkrementieren: 7 -> 17 	 j: 20, floor term:9
# i: 17
# ----
# Länge zum Ende von Zeitpunkt i = 17: 468
# i inkrementieren: 17 -> 23 	 j: 24, floor term:5
# i: 23
# ----
# Länge zum Ende von Zeitpunkt i = 23: 294
# i inkrementieren: 23 -> 30 	 j: 31, floor term:6
# i: 30
# ----
# Länge zum Ende von Zeitpunkt i = 30: 490
# i inkrementieren: 30 -> 34 	 j: 35, floor term:3
# i: 34
# ----
# Länge zum Ende von Zeitpunkt i = 34: 490
# i inkrementieren: 34 -> 42 	 j: 44, floor term:7
# i: 42
# ----
# Länge zum Ende von Zeitpunkt i = 42: 499
# i inkrementieren: 42 -> 58 	 j: 63, floor term:15
# i: 58
# ----
# Länge zum Ende von Zeitpunkt i = 58: 502
# i inkrementieren: 58 -> 73 	 j: 77, floor term:14
# i: 73
# ----
# Länge zum Ende von Zeitpunkt i = 73: 488
# i inkrementieren: 73 -> 89 	 j: 93, floor term:15
# i: 89
# ----
# Länge zum Ende von Zeitpunkt i = 89: 512
# i inkrementieren: 89 -> 102 	 j: 106, floor term:12
# i: 102
# ----
# Länge zum Ende von Zeitpunkt i = 102: 505
# i inkrementieren: 102 -> 120 	 j: 125, floor term:17
# i: 120
# ----
# Länge zum Ende von Zeitpunkt i = 120: 258
# i inkrementieren: 120 -> 128 	 j: 130, floor term:7
# i: 128
# ----
# Länge zum Ende von Zeitpunkt i = 128: 414
# i inkrementieren: 128 -> 132 	 j: 132, floor term:3
# i: 132
# ----
# Länge zum Ende von Zeitpunkt i = 132: 480
# i inkrementieren: 132 -> 136 	 j: 136, floor term:3
# i: 136
# ----
# Länge zum Ende von Zeitpunkt i = 136: 461
# i inkrementieren: 136 -> 141 	 j: 142, floor term:4
# i: 141
# ----
# Länge zum Ende von Zeitpunkt i = 141: 424
# i inkrementieren: 141 -> 148 	 j: 149, floor term:6
# i: 148
# ----
# Länge zum Ende von Zeitpunkt i = 148: 489
# i inkrementieren: 148 -> 156 	 j: 158, floor term:7
# i: 156
# ----
# Länge zum Ende von Zeitpunkt i = 156: 510
# i inkrementieren: 156 -> 171 	 j: 175, floor term:14
# i: 171
# ----
# Länge zum Ende von Zeitpunkt i = 171: 493
# i inkrementieren: 171 -> 181 	 j: 183, floor term:9
# i: 181
# ----
# Länge zum Ende von Zeitpunkt i = 181: 293
# i inkrementieren: 181 -> 185 	 j: 185, floor term:3
# i: 185
# j == len(list) (vor else)
# i: 0
# ----
# Länge zum Ende von Zeitpunkt i = 0: 472
# i inkrementieren: 0 -> 5 	 j: 6, floor term:4
# i: 5
# ----
# Länge zum Ende von Zeitpunkt i = 5: 492
# i inkrementieren: 5 -> 15 	 j: 17, floor term:9
# i: 15
# ----
# Länge zum Ende von Zeitpunkt i = 15: 506
# i inkrementieren: 15 -> 26 	 j: 29, floor term:10
# i: 26
# ----
# Länge zum Ende von Zeitpunkt i = 26: 501
# i inkrementieren: 26 -> 37 	 j: 40, floor term:10
# i: 37
# ----
# Länge zum Ende von Zeitpunkt i = 37: 500
# i inkrementieren: 37 -> 47 	 j: 50, floor term:9
# i: 47
# ----
# Länge zum Ende von Zeitpunkt i = 47: 401
# i inkrementieren: 47 -> 53 	 j: 54, floor term:5
# i: 53
# ----
# Länge zum Ende von Zeitpunkt i = 53: 444
# i inkrementieren: 53 -> 58 	 j: 59, floor term:4
# i: 58
# ----
# Länge zum Ende von Zeitpunkt i = 58: 502
# i inkrementieren: 58 -> 64 	 j: 65, floor term:5
# i: 64
# ----
# Länge zum Ende von Zeitpunkt i = 64: 501
# i inkrementieren: 64 -> 73 	 j: 75, floor term:8
# i: 73
# ----
# Länge zum Ende von Zeitpunkt i = 73: 402
# i inkrementieren: 73 -> 78 	 j: 79, floor term:4
# i: 78
# ----
# Länge zum Ende von Zeitpunkt i = 78: 474
# i inkrementieren: 78 -> 81 	 j: 81, floor term:2
# i: 81
# ----
# Länge zum Ende von Zeitpunkt i = 81: 484
# i inkrementieren: 81 -> 90 	 j: 92, floor term:8
# i: 90
# ----
# Länge zum Ende von Zeitpunkt i = 90: 403
# i inkrementieren: 90 -> 94 	 j: 95, floor term:3
# i: 94
# ----
# Länge zum Ende von Zeitpunkt i = 94: 484
# i inkrementieren: 94 -> 101 	 j: 103, floor term:6
# i: 101
# ----
# Länge zum Ende von Zeitpunkt i = 101: 504
# i inkrementieren: 101 -> 112 	 j: 115, floor term:10
# i: 112
# ----
# Länge zum Ende von Zeitpunkt i = 112: 511
# i inkrementieren: 112 -> 122 	 j: 124, floor term:9
# i: 122
# ----
# Länge zum Ende von Zeitpunkt i = 122: 453
# i inkrementieren: 122 -> 132 	 j: 134, floor term:9
# i: 132
# ----
# Länge zum Ende von Zeitpunkt i = 132: 469
# i inkrementieren: 132 -> 139 	 j: 140, floor term:6
# i: 139
# ----
# Länge zum Ende von Zeitpunkt i = 139: 512
# i inkrementieren: 139 -> 150 	 j: 153, floor term:10
# i: 150
# ----
# Länge zum Ende von Zeitpunkt i = 150: 385
# i inkrementieren: 150 -> 160 	 j: 162, floor term:9
# i: 160
# ----
# Länge zum Ende von Zeitpunkt i = 160: 497
# i inkrementieren: 160 -> 165 	 j: 166, floor term:4
# i: 165
# ----
# Länge zum Ende von Zeitpunkt i = 165: 497
# i inkrementieren: 165 -> 171 	 j: 172, floor term:5
# i: 171
# ----
# Länge zum Ende von Zeitpunkt i = 171: 496
# i inkrementieren: 171 -> 177 	 j: 178, floor term:5
# i: 177
# ----
# Länge zum Ende von Zeitpunkt i = 177: 400
# i inkrementieren: 177 -> 182 	 j: 183, floor term:4
# i: 182
# ----
# Länge zum Ende von Zeitpunkt i = 182: 429
# i inkrementieren: 182 -> 186 	 j: 187, floor term:3
# i: 186
# ----
# Länge zum Ende von Zeitpunkt i = 186: 504
# i inkrementieren: 186 -> 194 	 j: 196, floor term:7
# i: 194
# ----
# Länge zum Ende von Zeitpunkt i = 194: 487
# i inkrementieren: 194 -> 202 	 j: 204, floor term:7
# i: 202
# ----
# Länge zum Ende von Zeitpunkt i = 202: 506
# i inkrementieren: 202 -> 209 	 j: 210, floor term:6
# i: 209
# ----
# Länge zum Ende von Zeitpunkt i = 209: 511
# i inkrementieren: 209 -> 216 	 j: 217, floor term:6
# i: 216
# ----
# Länge zum Ende von Zeitpunkt i = 216: 511
# i inkrementieren: 216 -> 223 	 j: 225, floor term:6
# i: 223
# ----
# Länge zum Ende von Zeitpunkt i = 223: 489
# i inkrementieren: 223 -> 233 	 j: 235, floor term:9
# i: 233
# ----
# Länge zum Ende von Zeitpunkt i = 233: 453
# i inkrementieren: 233 -> 243 	 j: 245, floor term:9
# i: 243
# j == len(list) (vor else)
# i: 0
# ----
# Länge zum Ende von Zeitpunkt i = 0: 488
# i inkrementieren: 0 -> 12 	 j: 15, floor term:11
# i: 12
# ----
# Länge zum Ende von Zeitpunkt i = 12: 497
# i inkrementieren: 12 -> 20 	 j: 22, floor term:7
# i: 20
# ----
# Länge zum Ende von Zeitpunkt i = 20: 437
# i inkrementieren: 20 -> 27 	 j: 28, floor term:6
# i: 27
# ----
# Länge zum Ende von Zeitpunkt i = 27: 460
# i inkrementieren: 27 -> 33 	 j: 34, floor term:5
# i: 33
# ----
# Länge zum Ende von Zeitpunkt i = 33: 467
# i inkrementieren: 33 -> 38 	 j: 39, floor term:4
# i: 38
# ----
# Länge zum Ende von Zeitpunkt i = 38: 281
# i inkrementieren: 38 -> 41 	 j: 41, floor term:2
# i: 41
# ----
# Länge zum Ende von Zeitpunkt i = 41: 455
# i inkrementieren: 41 -> 43 	 j: 43, floor term:1
# i: 43
# ----
# Länge zum Ende von Zeitpunkt i = 43: 421
# i inkrementieren: 43 -> 48 	 j: 49, floor term:4
# i: 48
# ----
# Länge zum Ende von Zeitpunkt i = 48: 475
# i inkrementieren: 48 -> 55 	 j: 56, floor term:6
# i: 55
# ----
# Länge zum Ende von Zeitpunkt i = 55: 511
# i inkrementieren: 55 -> 60 	 j: 61, floor term:4
# i: 60
# ----
# Länge zum Ende von Zeitpunkt i = 60: 321
# i inkrementieren: 60 -> 64 	 j: 65, floor term:3
# i: 64
# ----
# Länge zum Ende von Zeitpunkt i = 64: 501
# i inkrementieren: 64 -> 69 	 j: 70, floor term:4
# i: 69
# ----
# Länge zum Ende von Zeitpunkt i = 69: 502
# i inkrementieren: 69 -> 81 	 j: 84, floor term:11
# i: 81
# ----
# Länge zum Ende von Zeitpunkt i = 81: 452
# i inkrementieren: 81 -> 95 	 j: 99, floor term:13
# i: 95
# ----
# Länge zum Ende von Zeitpunkt i = 95: 454
# i inkrementieren: 95 -> 104 	 j: 106, floor term:8
# i: 104
# ----
# Länge zum Ende von Zeitpunkt i = 104: 319
# i inkrementieren: 104 -> 109 	 j: 110, floor term:4
# i: 109
# ----
# Länge zum Ende von Zeitpunkt i = 109: 461
# i inkrementieren: 109 -> 113 	 j: 113, floor term:3
# i: 113
# ----
# Länge zum Ende von Zeitpunkt i = 113: 510
# i inkrementieren: 113 -> 120 	 j: 122, floor term:6
# i: 120
# ----
# Länge zum Ende von Zeitpunkt i = 120: 509
# i inkrementieren: 120 -> 129 	 j: 131, floor term:8
# i: 129
# ----
# Länge zum Ende von Zeitpunkt i = 129: 488
# i inkrementieren: 129 -> 138 	 j: 140, floor term:8
# i: 138
# ----
# Länge zum Ende von Zeitpunkt i = 138: 492
# i inkrementieren: 138 -> 152 	 j: 156, floor term:13
# i: 152
# ----
# Länge zum Ende von Zeitpunkt i = 152: 465
# i inkrementieren: 152 -> 163 	 j: 166, floor term:10
# i: 163
# ----
# Länge zum Ende von Zeitpunkt i = 163: 470
# i inkrementieren: 163 -> 174 	 j: 177, floor term:10
# i: 174
# ----
# Länge zum Ende von Zeitpunkt i = 174: 510
# i inkrementieren: 174 -> 191 	 j: 196, floor term:16
# i: 191
# ----
# Länge zum Ende von Zeitpunkt i = 191: 480
# i inkrementieren: 191 -> 201 	 j: 204, floor term:9
# i: 201
# ----
# Länge zum Ende von Zeitpunkt i = 201: 490
# i inkrementieren: 201 -> 213 	 j: 216, floor term:11
# i: 213
# ----
# Länge zum Ende von Zeitpunkt i = 213: 490
# i inkrementieren: 213 -> 219 	 j: 220, floor term:5
# i: 219
# ----
# Länge zum Ende von Zeitpunkt i = 219: 423
# i inkrementieren: 219 -> 224 	 j: 225, floor term:4
# i: 224
# ----
# Länge zum Ende von Zeitpunkt i = 224: 396
# i inkrementieren: 224 -> 231 	 j: 233, floor term:6
# i: 231
# ----
# Länge zum Ende von Zeitpunkt i = 231: 482
# i inkrementieren: 231 -> 243 	 j: 246, floor term:11
# i: 243
# ----
# Länge zum Ende von Zeitpunkt i = 243: 478
# i inkrementieren: 243 -> 252 	 j: 254, floor term:8
# i: 252
# ----
# Länge zum Ende von Zeitpunkt i = 252: 486
# i inkrementieren: 252 -> 258 	 j: 259, floor term:5
# i: 258
# ----
# Länge zum Ende von Zeitpunkt i = 258: 502
# i inkrementieren: 258 -> 265 	 j: 267, floor term:6
# i: 265
# ----
# Länge zum Ende von Zeitpunkt i = 265: 489
# i inkrementieren: 265 -> 275 	 j: 277, floor term:9
# i: 275
# ----
# Länge zum Ende von Zeitpunkt i = 275: 495
# i inkrementieren: 275 -> 285 	 j: 288, floor term:9
# i: 285
# ----
# Länge zum Ende von Zeitpunkt i = 285: 182
# i inkrementieren: 285 -> 290 	 j: 291, floor term:4
# i: 290
# ----
# Länge zum Ende von Zeitpunkt i = 290: 475
# i inkrementieren: 290 -> 295 	 j: 296, floor term:4
# i: 295
# ----
# Länge zum Ende von Zeitpunkt i = 295: 480
# i inkrementieren: 295 -> 305 	 j: 308, floor term:9
# i: 305
# ----
# Länge zum Ende von Zeitpunkt i = 305: 506
# i inkrementieren: 305 -> 312 	 j: 314, floor term:6
# i: 312
# ----
# Länge zum Ende von Zeitpunkt i = 312: 335
# i inkrementieren: 312 -> 319 	 j: 320, floor term:6
# i: 319
# ----
# Länge zum Ende von Zeitpunkt i = 319: 458
# i inkrementieren: 319 -> 326 	 j: 327, floor term:6
# i: 326
# ----
# Länge zum Ende von Zeitpunkt i = 326: 512
# i inkrementieren: 326 -> 331 	 j: 332, floor term:4
# i: 331
# ----
# Länge zum Ende von Zeitpunkt i = 331: 500
# i inkrementieren: 331 -> 340 	 j: 342, floor term:8
# i: 340
# ----
# Länge zum Ende von Zeitpunkt i = 340: 496
# i inkrementieren: 340 -> 352 	 j: 355, floor term:11
# i: 352
# ----
# Länge zum Ende von Zeitpunkt i = 352: 421
# i inkrementieren: 352 -> 364 	 j: 367, floor term:11
# i: 364
# ----
# Länge zum Ende von Zeitpunkt i = 364: 511
# i inkrementieren: 364 -> 370 	 j: 371, floor term:5
# i: 370
# ----
# Länge zum Ende von Zeitpunkt i = 370: 466
# i inkrementieren: 370 -> 374 	 j: 374, floor term:3
# i: 374
# j == len(list)
# i: 0
# ----
# Länge zum Ende von Zeitpunkt i = 0: 489
# i inkrementieren: 0 -> 13 	 j: 16, floor term:12
# i: 13
# ----
# Länge zum Ende von Zeitpunkt i = 13: 447
# i inkrementieren: 13 -> 23 	 j: 26, floor term:9
# i: 23
# ----
# Länge zum Ende von Zeitpunkt i = 23: 477
# i inkrementieren: 23 -> 30 	 j: 32, floor term:6
# i: 30
# ----
# Länge zum Ende von Zeitpunkt i = 30: 490
# i inkrementieren: 30 -> 37 	 j: 39, floor term:6
# i: 37
# ----
# Länge zum Ende von Zeitpunkt i = 37: 501
# i inkrementieren: 37 -> 44 	 j: 45, floor term:6
# i: 44
# ----
# Länge zum Ende von Zeitpunkt i = 44: 489
# i inkrementieren: 44 -> 51 	 j: 52, floor term:6
# i: 51
# ----
# Länge zum Ende von Zeitpunkt i = 51: 238
# i inkrementieren: 51 -> 56 	 j: 57, floor term:4
# i: 56
# ----
# Länge zum Ende von Zeitpunkt i = 56: 478
# i inkrementieren: 56 -> 60 	 j: 60, floor term:3
# i: 60
# ----
# Länge zum Ende von Zeitpunkt i = 60: 471
# i inkrementieren: 60 -> 70 	 j: 72, floor term:9
# i: 70
# ----
# Länge zum Ende von Zeitpunkt i = 70: 461
# i inkrementieren: 70 -> 79 	 j: 81, floor term:8
# i: 79
# ----
# Länge zum Ende von Zeitpunkt i = 79: 481
# i inkrementieren: 79 -> 87 	 j: 89, floor term:7
# i: 87
# ----
# Länge zum Ende von Zeitpunkt i = 87: 455
# i inkrementieren: 87 -> 98 	 j: 101, floor term:10
# i: 98
# ----
# Länge zum Ende von Zeitpunkt i = 98: 489
# i inkrementieren: 98 -> 110 	 j: 113, floor term:11
# i: 110
# ----
# Länge zum Ende von Zeitpunkt i = 110: 512
# i inkrementieren: 110 -> 124 	 j: 128, floor term:13
# i: 124
# ----
# Länge zum Ende von Zeitpunkt i = 124: 501
# i inkrementieren: 124 -> 134 	 j: 136, floor term:9
# i: 134
# ----
# Länge zum Ende von Zeitpunkt i = 134: 378
# i inkrementieren: 134 -> 141 	 j: 142, floor term:6
# i: 141
# ----
# Länge zum Ende von Zeitpunkt i = 141: 499
# i inkrementieren: 141 -> 145 	 j: 145, floor term:3
# i: 145
# ----
# Länge zum Ende von Zeitpunkt i = 145: 501
# i inkrementieren: 145 -> 155 	 j: 157, floor term:9
# i: 155
# ----
# Länge zum Ende von Zeitpunkt i = 155: 489
# i inkrementieren: 155 -> 173 	 j: 178, floor term:17
# i: 173
# ----
# Länge zum Ende von Zeitpunkt i = 173: 508
# i inkrementieren: 173 -> 187 	 j: 191, floor term:13
# i: 187
# ----
# Länge zum Ende von Zeitpunkt i = 187: 487
# i inkrementieren: 187 -> 201 	 j: 205, floor term:13
# i: 201
# ----
# Länge zum Ende von Zeitpunkt i = 201: 508
# i inkrementieren: 201 -> 213 	 j: 216, floor term:11
# i: 213
# ----
# Länge zum Ende von Zeitpunkt i = 213: 397
# i inkrementieren: 213 -> 224 	 j: 227, floor term:10
# i: 224
# ----
# Länge zum Ende von Zeitpunkt i = 224: 506
# i inkrementieren: 224 -> 231 	 j: 233, floor term:6
# i: 231
# ----
# Länge zum Ende von Zeitpunkt i = 231: 511
# i inkrementieren: 231 -> 242 	 j: 245, floor term:10
# i: 242
# ----
# Länge zum Ende von Zeitpunkt i = 242: 422
# i inkrementieren: 242 -> 251 	 j: 253, floor term:8
# i: 251
# ----
# Länge zum Ende von Zeitpunkt i = 251: 439
# i inkrementieren: 251 -> 256 	 j: 257, floor term:4
# i: 256
# ----
# Länge zum Ende von Zeitpunkt i = 256: 326
# i inkrementieren: 256 -> 263 	 j: 264, floor term:6
# i: 263
# ----
# Länge zum Ende von Zeitpunkt i = 263: 13
# i inkrementieren: 263 -> 264 	 j: 264, floor term:0
# i: 264
# ----
# Länge zum Ende von Zeitpunkt i = 264: 0
# i inkrementieren: 264 -> 265 	 j: 264, floor term:0
# i: 265
# ----
# Länge zum Ende von Zeitpunkt i = 265: 438
# i inkrementieren: 265 -> 274 	 j: 276, floor term:8
# i: 274
# ----
# Länge zum Ende von Zeitpunkt i = 274: 360
# i inkrementieren: 274 -> 278 	 j: 278, floor term:3
# i: 278
# ----
# Länge zum Ende von Zeitpunkt i = 278: 508
# i inkrementieren: 278 -> 285 	 j: 287, floor term:6
# i: 285
# ----
# Länge zum Ende von Zeitpunkt i = 285: 507
# i inkrementieren: 285 -> 301 	 j: 305, floor term:15
# i: 301
# ----
# Länge zum Ende von Zeitpunkt i = 301: 490
# i inkrementieren: 301 -> 316 	 j: 320, floor term:14
# i: 316
# ----
# Länge zum Ende von Zeitpunkt i = 316: 387
# i inkrementieren: 316 -> 327 	 j: 330, floor term:10
# i: 327
# ----
# Länge zum Ende von Zeitpunkt i = 327: 489
# i inkrementieren: 327 -> 339 	 j: 342, floor term:11
# i: 339
# ----
# Länge zum Ende von Zeitpunkt i = 339: 408
# i inkrementieren: 339 -> 352 	 j: 355, floor term:12
# i: 352
# ----
# Länge zum Ende von Zeitpunkt i = 352: 511
# i inkrementieren: 352 -> 362 	 j: 365, floor term:9
# i: 362
# ----
# Länge zum Ende von Zeitpunkt i = 362: 333
# i inkrementieren: 362 -> 367 	 j: 368, floor term:4
# i: 367
# ----
# Länge zum Ende von Zeitpunkt i = 367: 495
# i inkrementieren: 367 -> 377 	 j: 379, floor term:9
# i: 377
# ----
# Länge zum Ende von Zeitpunkt i = 377: 426
# i inkrementieren: 377 -> 385 	 j: 387, floor term:7
# i: 385
# ----
# Länge zum Ende von Zeitpunkt i = 385: 435
# i inkrementieren: 385 -> 388 	 j: 388, floor term:2
# i: 388
# ----
# Länge zum Ende von Zeitpunkt i = 388: 314
# i inkrementieren: 388 -> 389 	 j: 389, floor term:0
# i: 389
# ----
# Länge zum Ende von Zeitpunkt i = 389: 394
# i inkrementieren: 389 -> 392 	 j: 392, floor term:2
# i: 392
# ----
# Länge zum Ende von Zeitpunkt i = 392: 466
# i inkrementieren: 392 -> 395 	 j: 395, floor term:2
# i: 395
# ----
# Länge zum Ende von Zeitpunkt i = 395: 509
# i inkrementieren: 395 -> 404 	 j: 406, floor term:8
# i: 404
# ----
# Länge zum Ende von Zeitpunkt i = 404: 494
# i inkrementieren: 404 -> 412 	 j: 414, floor term:7
# i: 412
# ----
# Länge zum Ende von Zeitpunkt i = 412: 500
# i inkrementieren: 412 -> 428 	 j: 432, floor term:15
# i: 428
# ----
# Länge zum Ende von Zeitpunkt i = 428: 389
# i inkrementieren: 428 -> 438 	 j: 441, floor term:9
# i: 438
# ----
# Länge zum Ende von Zeitpunkt i = 438: 426
# i inkrementieren: 438 -> 445 	 j: 446, floor term:6
# i: 445
# ----
# Länge zum Ende von Zeitpunkt i = 445: 485
# i inkrementieren: 445 -> 450 	 j: 451, floor term:4
# i: 450
# ----
# Länge zum Ende von Zeitpunkt i = 450: 490
# i inkrementieren: 450 -> 456 	 j: 457, floor term:5
# i: 456
# ----
# Länge zum Ende von Zeitpunkt i = 456: 469
# i inkrementieren: 456 -> 469 	 j: 472, floor term:12
# i: 469
# ----
# Länge zum Ende von Zeitpunkt i = 469: 388
# i inkrementieren: 469 -> 474 	 j: 475, floor term:4
# i: 474
# ----
# Länge zum Ende von Zeitpunkt i = 474: 317
# i inkrementieren: 474 -> 477 	 j: 477, floor term:2
# i: 477
# ----
# Länge zum Ende von Zeitpunkt i = 477: 511
# i inkrementieren: 477 -> 481 	 j: 482, floor term:3
# i: 481
# ----
# Länge zum Ende von Zeitpunkt i = 481: 431
# i inkrementieren: 481 -> 485 	 j: 485, floor term:3
# i: 485
# ----
# Länge zum Ende von Zeitpunkt i = 485: 456
# i inkrementieren: 485 -> 492 	 j: 494, floor term:6
# i: 492
# ----
# Länge zum Ende von Zeitpunkt i = 492: 507
# i inkrementieren: 492 -> 503 	 j: 506, floor term:10
# i: 503
# ----
# Länge zum Ende von Zeitpunkt i = 503: 506
# i inkrementieren: 503 -> 512 	 j: 514, floor term:8
# i: 512
# ----
# Länge zum Ende von Zeitpunkt i = 512: 512
# i inkrementieren: 512 -> 527 	 j: 531, floor term:14
# i: 527
# ----
# Länge zum Ende von Zeitpunkt i = 527: 508
# i inkrementieren: 527 -> 537 	 j: 540, floor term:9
# i: 537
# ----
# Länge zum Ende von Zeitpunkt i = 537: 496
# i inkrementieren: 537 -> 544 	 j: 545, floor term:6
# i: 544
# ----
# Länge zum Ende von Zeitpunkt i = 544: 276
# i inkrementieren: 544 -> 550 	 j: 551, floor term:5
# i: 550
# ----
# Länge zum Ende von Zeitpunkt i = 550: 496
# i inkrementieren: 550 -> 558 	 j: 560, floor term:7
# i: 558
# ----
# Länge zum Ende von Zeitpunkt i = 558: 476
# i inkrementieren: 558 -> 570 	 j: 573, floor term:11
# i: 570
# ----
# Länge zum Ende von Zeitpunkt i = 570: 505
# i inkrementieren: 570 -> 578 	 j: 580, floor term:7
# i: 578
# ----
# Länge zum Ende von Zeitpunkt i = 578: 471
# i inkrementieren: 578 -> 594 	 j: 598, floor term:15
# i: 594
# ----
# Länge zum Ende von Zeitpunkt i = 594: 456
# i inkrementieren: 594 -> 601 	 j: 603, floor term:6
# i: 601
# ----
# Länge zum Ende von Zeitpunkt i = 601: 394
# i inkrementieren: 601 -> 605 	 j: 606, floor term:3
# i: 605
# ----
# Länge zum Ende von Zeitpunkt i = 605: 512
# i inkrementieren: 605 -> 611 	 j: 612, floor term:5
# i: 611
# ----
# Länge zum Ende von Zeitpunkt i = 611: 343
# i inkrementieren: 611 -> 615 	 j: 615, floor term:3
# i: 615
# ----
# Länge zum Ende von Zeitpunkt i = 615: 497
# i inkrementieren: 615 -> 622 	 j: 623, floor term:6
# i: 622
# ----
# Länge zum Ende von Zeitpunkt i = 622: 462
# i inkrementieren: 622 -> 631 	 j: 633, floor term:8
# i: 631
# ----
# Länge zum Ende von Zeitpunkt i = 631: 466
# i inkrementieren: 631 -> 638 	 j: 639, floor term:6
# i: 638
# ----
# Länge zum Ende von Zeitpunkt i = 638: 408
# i inkrementieren: 638 -> 647 	 j: 649, floor term:8
# i: 647
# ----
# Länge zum Ende von Zeitpunkt i = 647: 488
# i inkrementieren: 647 -> 652 	 j: 653, floor term:4
# i: 652
# ----
# Länge zum Ende von Zeitpunkt i = 652: 476
# i inkrementieren: 652 -> 656 	 j: 656, floor term:3
# i: 656
# ----
# Länge zum Ende von Zeitpunkt i = 656: 504
# i inkrementieren: 656 -> 661 	 j: 662, floor term:4
# i: 661
# ----
# Länge zum Ende von Zeitpunkt i = 661: 490
# i inkrementieren: 661 -> 667 	 j: 668, floor term:5
# i: 667
# ----
# Länge zum Ende von Zeitpunkt i = 667: 355
# i inkrementieren: 667 -> 671 	 j: 672, floor term:3
# i: 671
# ----
# Länge zum Ende von Zeitpunkt i = 671: 485
# i inkrementieren: 671 -> 676 	 j: 677, floor term:4
# i: 676
# ----
# Länge zum Ende von Zeitpunkt i = 676: 511
# i inkrementieren: 676 -> 683 	 j: 684, floor term:6
# i: 683
# ----
# Länge zum Ende von Zeitpunkt i = 683: 418
# i inkrementieren: 683 -> 690 	 j: 691, floor term:6
# i: 690
# ----
# Länge zum Ende von Zeitpunkt i = 690: 445
# i inkrementieren: 690 -> 700 	 j: 703, floor term:9
# i: 700
# ----
# Länge zum Ende von Zeitpunkt i = 700: 86
# i inkrementieren: 700 -> 703 	 j: 703, floor term:2
# i: 703
# ----
# Länge zum Ende von Zeitpunkt i = 703: 483
# i inkrementieren: 703 -> 704 	 j: 704, floor term:0
# i: 704
# ----
# Länge zum Ende von Zeitpunkt i = 704: 509
# i inkrementieren: 704 -> 712 	 j: 714, floor term:7
# i: 712
# ----
# Länge zum Ende von Zeitpunkt i = 712: 446
# i inkrementieren: 712 -> 718 	 j: 719, floor term:5
# i: 718
# ----
# Länge zum Ende von Zeitpunkt i = 718: 326
# i inkrementieren: 718 -> 723 	 j: 724, floor term:4
# i: 723
# ----
# Länge zum Ende von Zeitpunkt i = 723: 506
# i inkrementieren: 723 -> 727 	 j: 728, floor term:3
# i: 727
# ----
# Länge zum Ende von Zeitpunkt i = 727: 512
# i inkrementieren: 727 -> 737 	 j: 739, floor term:9
# i: 737
# ----
# Länge zum Ende von Zeitpunkt i = 737: 463
# i inkrementieren: 737 -> 742 	 j: 743, floor term:4
# i: 742
# ----
# Länge zum Ende von Zeitpunkt i = 742: 491
# i inkrementieren: 742 -> 750 	 j: 752, floor term:7
# i: 750
# ----
# Länge zum Ende von Zeitpunkt i = 750: 511
# i inkrementieren: 750 -> 762 	 j: 765, floor term:11
# i: 762
# ----
# Länge zum Ende von Zeitpunkt i = 762: 498
# i inkrementieren: 762 -> 772 	 j: 775, floor term:9
# i: 772
# ----
# Länge zum Ende von Zeitpunkt i = 772: 426
# i inkrementieren: 772 -> 784 	 j: 787, floor term:11
# i: 784
# ----
# Länge zum Ende von Zeitpunkt i = 784: 435
# i inkrementieren: 784 -> 791 	 j: 793, floor term:6
# i: 791
# ----
# Länge zum Ende von Zeitpunkt i = 791: 425
# i inkrementieren: 791 -> 798 	 j: 800, floor term:6
# i: 798
# ----
# Länge zum Ende von Zeitpunkt i = 798: 349
# i inkrementieren: 798 -> 802 	 j: 802, floor term:3
# i: 802
# j == len(list) (vor else)
# i: 0
# ----
# Länge zum Ende von Zeitpunkt i = 0: 410
# i inkrementieren: 0 -> 7 	 j: 9, floor term:6
# i: 7
# ----
# Länge zum Ende von Zeitpunkt i = 7: 476
# i inkrementieren: 7 -> 13 	 j: 14, floor term:5
# i: 13
# ----
# Länge zum Ende von Zeitpunkt i = 13: 483
# i inkrementieren: 13 -> 20 	 j: 21, floor term:6
# i: 20
# ----
# Länge zum Ende von Zeitpunkt i = 20: 468
# i inkrementieren: 20 -> 30 	 j: 32, floor term:9
# i: 30
# ----
# Länge zum Ende von Zeitpunkt i = 30: 501
# i inkrementieren: 30 -> 37 	 j: 38, floor term:6
# i: 37
# ----
# Länge zum Ende von Zeitpunkt i = 37: 456
# i inkrementieren: 37 -> 49 	 j: 52, floor term:11
# i: 49
# ----
# Länge zum Ende von Zeitpunkt i = 49: 481
# i inkrementieren: 49 -> 56 	 j: 58, floor term:6
# i: 56
# ----
# Länge zum Ende von Zeitpunkt i = 56: 509
# i inkrementieren: 56 -> 64 	 j: 66, floor term:7
# i: 64
# ----
# Länge zum Ende von Zeitpunkt i = 64: 371
# i inkrementieren: 64 -> 69 	 j: 70, floor term:4
# i: 69
# ----
# Länge zum Ende von Zeitpunkt i = 69: 496
# i inkrementieren: 69 -> 73 	 j: 74, floor term:3
# i: 73
# ----
# Länge zum Ende von Zeitpunkt i = 73: 442
# i inkrementieren: 73 -> 85 	 j: 88, floor term:11
# i: 85
# ----
# Länge zum Ende von Zeitpunkt i = 85: 449
# i inkrementieren: 85 -> 92 	 j: 93, floor term:6
# i: 92
# ----
# Länge zum Ende von Zeitpunkt i = 92: 495
# i inkrementieren: 92 -> 99 	 j: 101, floor term:6
# i: 99
# ----
# Länge zum Ende von Zeitpunkt i = 99: 504
# i inkrementieren: 99 -> 110 	 j: 113, floor term:10
# i: 110
# ----
# Länge zum Ende von Zeitpunkt i = 110: 503
# i inkrementieren: 110 -> 126 	 j: 130, floor term:15
# i: 126
# ----
# Länge zum Ende von Zeitpunkt i = 126: 488
# i inkrementieren: 126 -> 143 	 j: 148, floor term:16
# i: 143
# ----
# Länge zum Ende von Zeitpunkt i = 143: 469
# i inkrementieren: 143 -> 155 	 j: 158, floor term:11
# i: 155
# ----
# Länge zum Ende von Zeitpunkt i = 155: 508
# i inkrementieren: 155 -> 168 	 j: 172, floor term:12
# i: 168
# ----
# Länge zum Ende von Zeitpunkt i = 168: 493
# i inkrementieren: 168 -> 179 	 j: 182, floor term:10
# i: 179
# ----
# Länge zum Ende von Zeitpunkt i = 179: 508
# i inkrementieren: 179 -> 190 	 j: 193, floor term:10
# i: 190
# ----
# Länge zum Ende von Zeitpunkt i = 190: 486
# i inkrementieren: 190 -> 206 	 j: 210, floor term:15
# i: 206
# ----
# Länge zum Ende von Zeitpunkt i = 206: 448
# i inkrementieren: 206 -> 215 	 j: 217, floor term:8
# i: 215
# j == len(list) (vor else)
# i: 0
# ----
# Länge zum Ende von Zeitpunkt i = 0: 428
# i inkrementieren: 0 -> 4 	 j: 4, floor term:3
# i: 4
# ----
# Länge zum Ende von Zeitpunkt i = 4: 512
# i inkrementieren: 4 -> 25 	 j: 31, floor term:20
# i: 25
# ----
# Länge zum Ende von Zeitpunkt i = 25: 472
# i inkrementieren: 25 -> 39 	 j: 43, floor term:13
# i: 39
# ----
# Länge zum Ende von Zeitpunkt i = 39: 466
# i inkrementieren: 39 -> 46 	 j: 47, floor term:6
# i: 46
# ----
# Länge zum Ende von Zeitpunkt i = 46: 505
# i inkrementieren: 46 -> 65 	 j: 70, floor term:18
# i: 65
# ----
# Länge zum Ende von Zeitpunkt i = 65: 495
# i inkrementieren: 65 -> 90 	 j: 98, floor term:24
# i: 90
# ----
# Länge zum Ende von Zeitpunkt i = 90: 505
# i inkrementieren: 90 -> 101 	 j: 104, floor term:10
# i: 101
# ----
# Länge zum Ende von Zeitpunkt i = 101: 501
# i inkrementieren: 101 -> 110 	 j: 112, floor term:8
# i: 110
# ----
# Länge zum Ende von Zeitpunkt i = 110: 503
# i inkrementieren: 110 -> 124 	 j: 128, floor term:13
# i: 124
# ----
# Länge zum Ende von Zeitpunkt i = 124: 511
# i inkrementieren: 124 -> 136 	 j: 139, floor term:11
# i: 136
# ----
# Länge zum Ende von Zeitpunkt i = 136: 504
# i inkrementieren: 136 -> 152 	 j: 156, floor term:15
# i: 152
# ----
# Länge zum Ende von Zeitpunkt i = 152: 448
# i inkrementieren: 152 -> 165 	 j: 169, floor term:12
# i: 165
# ----
# Länge zum Ende von Zeitpunkt i = 165: 504
# i inkrementieren: 165 -> 173 	 j: 175, floor term:7
# i: 173
# ----
# Länge zum Ende von Zeitpunkt i = 173: 452
# i inkrementieren: 173 -> 179 	 j: 180, floor term:5
# i: 179
# ----
# Länge zum Ende von Zeitpunkt i = 179: 466
# i inkrementieren: 179 -> 182 	 j: 182, floor term:2
# i: 182
# ----
# Länge zum Ende von Zeitpunkt i = 182: 459
# i inkrementieren: 182 -> 195 	 j: 199, floor term:12
# i: 195
# ----
# Länge zum Ende von Zeitpunkt i = 195: 509
# i inkrementieren: 195 -> 210 	 j: 214, floor term:14
# i: 210
# ----
# Länge zum Ende von Zeitpunkt i = 210: 468
# i inkrementieren: 210 -> 223 	 j: 227, floor term:12
# i: 223
# ----
# Länge zum Ende von Zeitpunkt i = 223: 479
# i inkrementieren: 223 -> 236 	 j: 240, floor term:12
# i: 236
# ----
# Länge zum Ende von Zeitpunkt i = 236: 465
# i inkrementieren: 236 -> 243 	 j: 245, floor term:6
# i: 243
# ----
# Länge zum Ende von Zeitpunkt i = 243: 497
# i inkrementieren: 243 -> 254 	 j: 257, floor term:10
# i: 254
# ----
# Länge zum Ende von Zeitpunkt i = 254: 458
# i inkrementieren: 254 -> 265 	 j: 268, floor term:10
# i: 265
# ----
# Länge zum Ende von Zeitpunkt i = 265: 507
# i inkrementieren: 265 -> 274 	 j: 276, floor term:8
# i: 274
# ----
# Länge zum Ende von Zeitpunkt i = 274: 492
# i inkrementieren: 274 -> 287 	 j: 291, floor term:12
# i: 287
# ----
# Länge zum Ende von Zeitpunkt i = 287: 436
# i inkrementieren: 287 -> 291 	 j: 292, floor term:3
# i: 291
# ----
# Länge zum Ende von Zeitpunkt i = 291: 499
# i inkrementieren: 291 -> 295 	 j: 296, floor term:3
# i: 295
# ----
# Länge zum Ende von Zeitpunkt i = 295: 503
# i inkrementieren: 295 -> 308 	 j: 311, floor term:12
# i: 308
# ----
# Länge zum Ende von Zeitpunkt i = 308: 509
# i inkrementieren: 308 -> 319 	 j: 322, floor term:10
# i: 319
# ----
# Länge zum Ende von Zeitpunkt i = 319: 208
# i inkrementieren: 319 -> 325 	 j: 326, floor term:5
# i: 325
# ----
# Länge zum Ende von Zeitpunkt i = 325: 14
# i inkrementieren: 325 -> 326 	 j: 326, floor term:0
# i: 326
# ----
# Länge zum Ende von Zeitpunkt i = 326: 0
# i inkrementieren: 326 -> 327 	 j: 326, floor term:0
# i: 327
# ----
# Länge zum Ende von Zeitpunkt i = 327: 465
# i inkrementieren: 327 -> 336 	 j: 338, floor term:8
# i: 336
# ----
# Länge zum Ende von Zeitpunkt i = 336: 473
# i inkrementieren: 336 -> 348 	 j: 351, floor term:11
# i: 348
# ----
# Länge zum Ende von Zeitpunkt i = 348: 453
# i inkrementieren: 348 -> 360 	 j: 363, floor term:11
# i: 360
# ----
# Länge zum Ende von Zeitpunkt i = 360: 510
# i inkrementieren: 360 -> 374 	 j: 378, floor term:13
# i: 374
# j == len(list) (vor else)
# i: 0
# ----
# Länge zum Ende von Zeitpunkt i = 0: 480
# i inkrementieren: 0 -> 11 	 j: 14, floor term:10
# i: 11
# ----
# Länge zum Ende von Zeitpunkt i = 11: 371
# i inkrementieren: 11 -> 21 	 j: 24, floor term:9
# i: 21
# ----
# Länge zum Ende von Zeitpunkt i = 21: 461
# i inkrementieren: 21 -> 28 	 j: 30, floor term:6
# i: 28
# ----
# Länge zum Ende von Zeitpunkt i = 28: 505
# i inkrementieren: 28 -> 35 	 j: 36, floor term:6
# i: 35
# ----
# Länge zum Ende von Zeitpunkt i = 35: 500
# i inkrementieren: 35 -> 53 	 j: 58, floor term:17
# i: 53
# ----
# Länge zum Ende von Zeitpunkt i = 53: 268
# i inkrementieren: 53 -> 62 	 j: 64, floor term:8
# i: 62
# ----
# Länge zum Ende von Zeitpunkt i = 62: 35
# i inkrementieren: 62 -> 64 	 j: 64, floor term:1
# i: 64
# ----
# Länge zum Ende von Zeitpunkt i = 64: 0
# i inkrementieren: 64 -> 65 	 j: 64, floor term:0
# i: 65
# ----
# Länge zum Ende von Zeitpunkt i = 65: 423
# i inkrementieren: 65 -> 76 	 j: 79, floor term:10
# i: 76
# ----
# Länge zum Ende von Zeitpunkt i = 76: 507
# i inkrementieren: 76 -> 89 	 j: 92, floor term:12
# i: 89
# ----
# Länge zum Ende von Zeitpunkt i = 89: 488
# i inkrementieren: 89 -> 103 	 j: 107, floor term:13
# i: 103
# ----
# Länge zum Ende von Zeitpunkt i = 103: 499
# i inkrementieren: 103 -> 113 	 j: 116, floor term:9
# i: 113
# ----
# Länge zum Ende von Zeitpunkt i = 113: 505
# i inkrementieren: 113 -> 126 	 j: 130, floor term:12
# i: 126
# ----
# Länge zum Ende von Zeitpunkt i = 126: 499
# i inkrementieren: 126 -> 139 	 j: 142, floor term:12
# i: 139
# ----
# Länge zum Ende von Zeitpunkt i = 139: 445
# i inkrementieren: 139 -> 146 	 j: 148, floor term:6
# i: 146
# ----
# Länge zum Ende von Zeitpunkt i = 146: 330
# i inkrementieren: 146 -> 150 	 j: 150, floor term:3
# i: 150
# ----
# Länge zum Ende von Zeitpunkt i = 150: 402
# i inkrementieren: 150 -> 154 	 j: 154, floor term:3
# i: 154
# ----
# Länge zum Ende von Zeitpunkt i = 154: 463
# i inkrementieren: 154 -> 161 	 j: 162, floor term:6
# i: 161
# ----
# Länge zum Ende von Zeitpunkt i = 161: 303
# i inkrementieren: 161 -> 165 	 j: 165, floor term:3
# i: 165
# ----
# Länge zum Ende von Zeitpunkt i = 165: 449
# i inkrementieren: 165 -> 172 	 j: 174, floor term:6
# i: 172
# ----
# Länge zum Ende von Zeitpunkt i = 172: 276
# i inkrementieren: 172 -> 177 	 j: 178, floor term:4
# i: 177
# ----
# Länge zum Ende von Zeitpunkt i = 177: 426
# i inkrementieren: 177 -> 183 	 j: 184, floor term:5
# i: 183
# ----
# Länge zum Ende von Zeitpunkt i = 183: 464
# i inkrementieren: 183 -> 188 	 j: 189, floor term:4
# i: 188
# ----
# Länge zum Ende von Zeitpunkt i = 188: 467
# i inkrementieren: 188 -> 199 	 j: 202, floor term:10
# i: 199
# ----
# Länge zum Ende von Zeitpunkt i = 199: 465
# i inkrementieren: 199 -> 210 	 j: 213, floor term:10
# i: 210
# ----
# Länge zum Ende von Zeitpunkt i = 210: 460
# i inkrementieren: 210 -> 220 	 j: 222, floor term:9
# i: 220
# ----
# Länge zum Ende von Zeitpunkt i = 220: 492
# i inkrementieren: 220 -> 232 	 j: 235, floor term:11
# i: 232
# ----
# Länge zum Ende von Zeitpunkt i = 232: 476
# i inkrementieren: 232 -> 245 	 j: 248, floor term:12
# i: 245
# ----
# Länge zum Ende von Zeitpunkt i = 245: 456
# i inkrementieren: 245 -> 253 	 j: 255, floor term:7
# i: 253
# ----
# Länge zum Ende von Zeitpunkt i = 253: 454
# i inkrementieren: 253 -> 262 	 j: 264, floor term:8
# i: 262
# ----
# Länge zum Ende von Zeitpunkt i = 262: 157
# i inkrementieren: 262 -> 264 	 j: 264, floor term:1
# i: 264
# ----
# Länge zum Ende von Zeitpunkt i = 264: 483
# i inkrementieren: 264 -> 268 	 j: 269, floor term:3
# i: 268
# ----
# Länge zum Ende von Zeitpunkt i = 268: 469
# i inkrementieren: 268 -> 278 	 j: 281, floor term:9
# i: 278
# ----
# Länge zum Ende von Zeitpunkt i = 278: 512
# i inkrementieren: 278 -> 288 	 j: 291, floor term:9
# i: 288
# ----
# Länge zum Ende von Zeitpunkt i = 288: 268
# i inkrementieren: 288 -> 292 	 j: 292, floor term:3
# i: 292
# ----
# Länge zum Ende von Zeitpunkt i = 292: 0
# i inkrementieren: 292 -> 293 	 j: 292, floor term:0
# i: 293
# ----
# Länge zum Ende von Zeitpunkt i = 293: 464
# i inkrementieren: 293 -> 305 	 j: 308, floor term:11
# i: 305
# ----
# Länge zum Ende von Zeitpunkt i = 305: 506
# i inkrementieren: 305 -> 318 	 j: 321, floor term:12
# i: 318
# ----
# Länge zum Ende von Zeitpunkt i = 318: 478
# i inkrementieren: 318 -> 328 	 j: 331, floor term:9
# i: 328
# ----
# Länge zum Ende von Zeitpunkt i = 328: 317
# i inkrementieren: 328 -> 332 	 j: 333, floor term:3
# i: 332
# ----
# Länge zum Ende von Zeitpunkt i = 332: 10
# i inkrementieren: 332 -> 333 	 j: 333, floor term:0
# i: 333
# ----
# Länge zum Ende von Zeitpunkt i = 333: 0
# i inkrementieren: 333 -> 334 	 j: 333, floor term:0
# i: 334
# ----
# Länge zum Ende von Zeitpunkt i = 334: 470
# i inkrementieren: 334 -> 338 	 j: 339, floor term:3
# i: 338
# ----
# Länge zum Ende von Zeitpunkt i = 338: 470
# i inkrementieren: 338 -> 342 	 j: 343, floor term:3
# i: 342
# ----
# Länge zum Ende von Zeitpunkt i = 342: 482
# i inkrementieren: 342 -> 347 	 j: 348, floor term:4
# i: 347
# ----
# Länge zum Ende von Zeitpunkt i = 347: 463
# i inkrementieren: 347 -> 352 	 j: 353, floor term:4
# i: 352
# ----
# Länge zum Ende von Zeitpunkt i = 352: 482
# i inkrementieren: 352 -> 359 	 j: 361, floor term:6
# i: 359
# ----
# Länge zum Ende von Zeitpunkt i = 359: 491
# i inkrementieren: 359 -> 366 	 j: 368, floor term:6
# i: 366
# ----
# Länge zum Ende von Zeitpunkt i = 366: 498
# i inkrementieren: 366 -> 380 	 j: 384, floor term:13
# i: 380
# ----
# Länge zum Ende von Zeitpunkt i = 380: 400
# i inkrementieren: 380 -> 388 	 j: 390, floor term:7
# i: 388
# ----
# Länge zum Ende von Zeitpunkt i = 388: 495
# i inkrementieren: 388 -> 395 	 j: 397, floor term:6
# i: 395
# ----
# Länge zum Ende von Zeitpunkt i = 395: 340
# i inkrementieren: 395 -> 401 	 j: 402, floor term:5
# i: 401
# ----
# Länge zum Ende von Zeitpunkt i = 401: 508
# i inkrementieren: 401 -> 407 	 j: 408, floor term:5
# i: 407
# ----
# Länge zum Ende von Zeitpunkt i = 407: 498
# i inkrementieren: 407 -> 421 	 j: 425, floor term:13
# i: 421
# ----
# Länge zum Ende von Zeitpunkt i = 421: 447
# i inkrementieren: 421 -> 428 	 j: 429, floor term:6
# i: 428
# ----
# Länge zum Ende von Zeitpunkt i = 428: 499
# i inkrementieren: 428 -> 435 	 j: 436, floor term:6
# i: 435
# ----
# Länge zum Ende von Zeitpunkt i = 435: 504
# i inkrementieren: 435 -> 445 	 j: 448, floor term:9
# i: 445
# ----
# Länge zum Ende von Zeitpunkt i = 445: 447
# i inkrementieren: 445 -> 456 	 j: 459, floor term:10
# i: 456
# ----
# Länge zum Ende von Zeitpunkt i = 456: 440
# i inkrementieren: 456 -> 469 	 j: 472, floor term:12
# i: 469
# ----
# Länge zum Ende von Zeitpunkt i = 469: 455
# i inkrementieren: 469 -> 477 	 j: 479, floor term:7
# i: 477
# ----
# Länge zum Ende von Zeitpunkt i = 477: 512
# i inkrementieren: 477 -> 487 	 j: 489, floor term:9
# i: 487
# ----
# Länge zum Ende von Zeitpunkt i = 487: 474
# i inkrementieren: 487 -> 494 	 j: 496, floor term:6
# i: 494
# ----
# Länge zum Ende von Zeitpunkt i = 494: 458
# i inkrementieren: 494 -> 501 	 j: 503, floor term:6
# i: 501
# ----
# Länge zum Ende von Zeitpunkt i = 501: 496
# i inkrementieren: 501 -> 510 	 j: 512, floor term:8
# i: 510
# ----
# Länge zum Ende von Zeitpunkt i = 510: 116
# i inkrementieren: 510 -> 512 	 j: 512, floor term:1
# i: 512
# ----
# Länge zum Ende von Zeitpunkt i = 512: 452
# i inkrementieren: 512 -> 515 	 j: 515, floor term:2
# i: 515
# ----
# Länge zum Ende von Zeitpunkt i = 515: 475
# i inkrementieren: 515 -> 520 	 j: 521, floor term:4
# i: 520
# ----
# Länge zum Ende von Zeitpunkt i = 520: 493
# i inkrementieren: 520 -> 528 	 j: 530, floor term:7
# i: 528
# ----
# Länge zum Ende von Zeitpunkt i = 528: 454
# i inkrementieren: 528 -> 538 	 j: 541, floor term:9
# i: 538
# ----
# Länge zum Ende von Zeitpunkt i = 538: 462
# i inkrementieren: 538 -> 545 	 j: 547, floor term:6
# i: 545
# ----
# Länge zum Ende von Zeitpunkt i = 545: 379
# i inkrementieren: 545 -> 552 	 j: 554, floor term:6
# i: 552
# ----
# Länge zum Ende von Zeitpunkt i = 552: 451
# i inkrementieren: 552 -> 557 	 j: 558, floor term:4
# i: 557
# ----
# Länge zum Ende von Zeitpunkt i = 557: 458
# i inkrementieren: 557 -> 561 	 j: 561, floor term:3
# i: 561
# ----
# Länge zum Ende von Zeitpunkt i = 561: 507
# i inkrementieren: 561 -> 568 	 j: 570, floor term:6
# i: 568
# ----
# Länge zum Ende von Zeitpunkt i = 568: 484
# i inkrementieren: 568 -> 576 	 j: 578, floor term:7
# i: 576
# ----
# Länge zum Ende von Zeitpunkt i = 576: 452
# i inkrementieren: 576 -> 587 	 j: 590, floor term:10
# i: 587
# ----
# Länge zum Ende von Zeitpunkt i = 587: 495
# i inkrementieren: 587 -> 600 	 j: 603, floor term:12
# i: 600
# ----
# Länge zum Ende von Zeitpunkt i = 600: 484
# i inkrementieren: 600 -> 613 	 j: 616, floor term:12
# i: 613
# ----
# Länge zum Ende von Zeitpunkt i = 613: 478
# i inkrementieren: 613 -> 625 	 j: 628, floor term:11
# i: 625
# ----
# Länge zum Ende von Zeitpunkt i = 625: 506
# i inkrementieren: 625 -> 632 	 j: 634, floor term:6
# i: 632
# ----
# Länge zum Ende von Zeitpunkt i = 632: 467
# i inkrementieren: 632 -> 642 	 j: 645, floor term:9
# i: 642
# ----
# Länge zum Ende von Zeitpunkt i = 642: 422
# i inkrementieren: 642 -> 655 	 j: 658, floor term:12
# i: 655
# ----
# Länge zum Ende von Zeitpunkt i = 655: 512
# i inkrementieren: 655 -> 661 	 j: 662, floor term:5
# i: 661
# ----
# Länge zum Ende von Zeitpunkt i = 661: 495
# i inkrementieren: 661 -> 672 	 j: 675, floor term:10
# i: 672
# ----
# Länge zum Ende von Zeitpunkt i = 672: 281
# i inkrementieren: 672 -> 680 	 j: 682, floor term:7
# i: 680
# ----
# Länge zum Ende von Zeitpunkt i = 680: 455
# i inkrementieren: 680 -> 689 	 j: 691, floor term:8
# i: 689
# ----
# Länge zum Ende von Zeitpunkt i = 689: 500
# i inkrementieren: 689 -> 700 	 j: 703, floor term:10
# i: 700
# ----
# Länge zum Ende von Zeitpunkt i = 700: 393
# i inkrementieren: 700 -> 714 	 j: 718, floor term:13
# i: 714
# ----
# Länge zum Ende von Zeitpunkt i = 714: 451
# i inkrementieren: 714 -> 722 	 j: 724, floor term:7
# i: 722
# ----
# Länge zum Ende von Zeitpunkt i = 722: 487
# i inkrementieren: 722 -> 727 	 j: 728, floor term:4
# i: 727
# ----
# Länge zum Ende von Zeitpunkt i = 727: 507
# i inkrementieren: 727 -> 735 	 j: 737, floor term:7
# i: 735
# ----
# Länge zum Ende von Zeitpunkt i = 735: 508
# i inkrementieren: 735 -> 755 	 j: 761, floor term:19
# i: 755
# ----
# Länge zum Ende von Zeitpunkt i = 755: 495
# i inkrementieren: 755 -> 765 	 j: 767, floor term:9
# i: 765
# ----
# Länge zum Ende von Zeitpunkt i = 765: 498
# i inkrementieren: 765 -> 773 	 j: 775, floor term:7
# i: 773
# ----
# Länge zum Ende von Zeitpunkt i = 773: 498
# i inkrementieren: 773 -> 778 	 j: 779, floor term:4
# i: 778
# ----
# Länge zum Ende von Zeitpunkt i = 778: 479
# i inkrementieren: 778 -> 786 	 j: 788, floor term:7
# i: 786
# ----
# Länge zum Ende von Zeitpunkt i = 786: 296
# i inkrementieren: 786 -> 790 	 j: 791, floor term:3
# i: 790
# ----
# Länge zum Ende von Zeitpunkt i = 790: 98
# i inkrementieren: 790 -> 791 	 j: 791, floor term:0
# i: 791
# ----
# Länge zum Ende von Zeitpunkt i = 791: 484
# i inkrementieren: 791 -> 795 	 j: 796, floor term:3
# i: 795
# ----
# Länge zum Ende von Zeitpunkt i = 795: 485
# i inkrementieren: 795 -> 811 	 j: 815, floor term:15
# i: 811
# ----
# Länge zum Ende von Zeitpunkt i = 811: 500
# i inkrementieren: 811 -> 821 	 j: 824, floor term:9
# i: 821
# ----
# Länge zum Ende von Zeitpunkt i = 821: 472
# i inkrementieren: 821 -> 833 	 j: 836, floor term:11
# i: 833
# ----
# Länge zum Ende von Zeitpunkt i = 833: 496
# i inkrementieren: 833 -> 844 	 j: 847, floor term:10
# i: 844
# ----
# Länge zum Ende von Zeitpunkt i = 844: 511
# i inkrementieren: 844 -> 860 	 j: 864, floor term:15
# i: 860
# ----
# Länge zum Ende von Zeitpunkt i = 860: 490
# i inkrementieren: 860 -> 873 	 j: 876, floor term:12
# i: 873
# j == len(list) (vor else)
# i: 0
# ----
# Länge zum Ende von Zeitpunkt i = 0: 507
# i inkrementieren: 0 -> 10 	 j: 12, floor term:9
# i: 10
# ----
# Länge zum Ende von Zeitpunkt i = 10: 489
# i inkrementieren: 10 -> 22 	 j: 25, floor term:11
# i: 22
# ----
# Länge zum Ende von Zeitpunkt i = 22: 491
# i inkrementieren: 22 -> 32 	 j: 34, floor term:9
# i: 32
# ----
# Länge zum Ende von Zeitpunkt i = 32: 511
# i inkrementieren: 32 -> 41 	 j: 43, floor term:8
# i: 41
# ----
# Länge zum Ende von Zeitpunkt i = 41: 509
# i inkrementieren: 41 -> 55 	 j: 59, floor term:13
# i: 55
# ----
# Länge zum Ende von Zeitpunkt i = 55: 497
# i inkrementieren: 55 -> 71 	 j: 76, floor term:15
# i: 71
# ----
# Länge zum Ende von Zeitpunkt i = 71: 510
# i inkrementieren: 71 -> 84 	 j: 88, floor term:12
# i: 84
# ----
# Länge zum Ende von Zeitpunkt i = 84: 500
# i inkrementieren: 84 -> 105 	 j: 111, floor term:20
# i: 105
# ----
# Länge zum Ende von Zeitpunkt i = 105: 347
# i inkrementieren: 105 -> 115 	 j: 117, floor term:9
# i: 115
# ----
# Länge zum Ende von Zeitpunkt i = 115: 481
# i inkrementieren: 115 -> 122 	 j: 123, floor term:6
# i: 122
# ----
# Länge zum Ende von Zeitpunkt i = 122: 472
# i inkrementieren: 122 -> 129 	 j: 131, floor term:6
# i: 129
# ----
# Länge zum Ende von Zeitpunkt i = 129: 160
# i inkrementieren: 129 -> 131 	 j: 131, floor term:1
# i: 131
# ----
# Länge zum Ende von Zeitpunkt i = 131: 457
# i inkrementieren: 131 -> 134 	 j: 134, floor term:2
# i: 134
# ----
# Länge zum Ende von Zeitpunkt i = 134: 0
# i inkrementieren: 134 -> 135 	 j: 134, floor term:0
# i: 135
# ----
# Länge zum Ende von Zeitpunkt i = 135: 476
# i inkrementieren: 135 -> 146 	 j: 149, floor term:10
# i: 146
# ----
# Länge zum Ende von Zeitpunkt i = 146: 447
# i inkrementieren: 146 -> 157 	 j: 160, floor term:10
# i: 157
# ----
# Länge zum Ende von Zeitpunkt i = 157: 492
# i inkrementieren: 157 -> 170 	 j: 174, floor term:12
# i: 170
# ----
# Länge zum Ende von Zeitpunkt i = 170: 410
# i inkrementieren: 170 -> 177 	 j: 178, floor term:6
# i: 177
# ----
# Länge zum Ende von Zeitpunkt i = 177: 336
# i inkrementieren: 177 -> 181 	 j: 182, floor term:3
# i: 181
# ----
# Länge zum Ende von Zeitpunkt i = 181: 441
# i inkrementieren: 181 -> 188 	 j: 190, floor term:6
# i: 188
# ----
# Länge zum Ende von Zeitpunkt i = 188: 475
# i inkrementieren: 188 -> 192 	 j: 192, floor term:3
# i: 192
# ----
# Länge zum Ende von Zeitpunkt i = 192: 507
# i inkrementieren: 192 -> 204 	 j: 207, floor term:11
# i: 204
# ----
# Länge zum Ende von Zeitpunkt i = 204: 458
# i inkrementieren: 204 -> 211 	 j: 212, floor term:6
# i: 211
# ----
# Länge zum Ende von Zeitpunkt i = 211: 475
# i inkrementieren: 211 -> 220 	 j: 222, floor term:8
# i: 220
# ----
# Länge zum Ende von Zeitpunkt i = 220: 489
# i inkrementieren: 220 -> 230 	 j: 233, floor term:9
# i: 230
# ----
# Länge zum Ende von Zeitpunkt i = 230: 486
# i inkrementieren: 230 -> 239 	 j: 241, floor term:8
# i: 239
# ----
# Länge zum Ende von Zeitpunkt i = 239: 502
# i inkrementieren: 239 -> 251 	 j: 254, floor term:11
# i: 251
# ----
# Länge zum Ende von Zeitpunkt i = 251: 511
# i inkrementieren: 251 -> 266 	 j: 270, floor term:14
# i: 266
# ----
# Länge zum Ende von Zeitpunkt i = 266: 499
# i inkrementieren: 266 -> 276 	 j: 278, floor term:9
# i: 276
# ----
# Länge zum Ende von Zeitpunkt i = 276: 494
# i inkrementieren: 276 -> 287 	 j: 290, floor term:10
# i: 287
# ----
# Länge zum Ende von Zeitpunkt i = 287: 435
# i inkrementieren: 287 -> 297 	 j: 299, floor term:9
# i: 297
# ----
# Länge zum Ende von Zeitpunkt i = 297: 492
# i inkrementieren: 297 -> 309 	 j: 312, floor term:11
# i: 309
# ----
# Länge zum Ende von Zeitpunkt i = 309: 484
# i inkrementieren: 309 -> 321 	 j: 324, floor term:11
# i: 321
# ----
# Länge zum Ende von Zeitpunkt i = 321: 505
# i inkrementieren: 321 -> 340 	 j: 346, floor term:18
# i: 340
# ----
# Länge zum Ende von Zeitpunkt i = 340: 455
# i inkrementieren: 340 -> 353 	 j: 356, floor term:12
# i: 353
# ----
# Länge zum Ende von Zeitpunkt i = 353: 508
# i inkrementieren: 353 -> 360 	 j: 362, floor term:6
# i: 360
# ----
# Länge zum Ende von Zeitpunkt i = 360: 465
# i inkrementieren: 360 -> 373 	 j: 377, floor term:12
# i: 373
# ----
# Länge zum Ende von Zeitpunkt i = 373: 512
# i inkrementieren: 373 -> 389 	 j: 394, floor term:15
# i: 389
# ----
# Länge zum Ende von Zeitpunkt i = 389: 196
# i inkrementieren: 389 -> 396 	 j: 398, floor term:6
# i: 396
# ----
# Länge zum Ende von Zeitpunkt i = 396: 429
# i inkrementieren: 396 -> 400 	 j: 400, floor term:3
# i: 400
# ----
# Länge zum Ende von Zeitpunkt i = 400: 502
# i inkrementieren: 400 -> 404 	 j: 405, floor term:3
# i: 404
# ----
# Länge zum Ende von Zeitpunkt i = 404: 106
# i inkrementieren: 404 -> 406 	 j: 406, floor term:1
# i: 406
# ----
# Länge zum Ende von Zeitpunkt i = 406: 0
# i inkrementieren: 406 -> 407 	 j: 406, floor term:0
# i: 407
# ----
# Länge zum Ende von Zeitpunkt i = 407: 428
# i inkrementieren: 407 -> 413 	 j: 414, floor term:5
# i: 413
# ----
# Länge zum Ende von Zeitpunkt i = 413: 508
# i inkrementieren: 413 -> 424 	 j: 427, floor term:10
# i: 424
# ----
# Länge zum Ende von Zeitpunkt i = 424: 424
# i inkrementieren: 424 -> 431 	 j: 432, floor term:6
# i: 431
# ----
# Länge zum Ende von Zeitpunkt i = 431: 488
# i inkrementieren: 431 -> 440 	 j: 442, floor term:8
# i: 440
# ----
# Länge zum Ende von Zeitpunkt i = 440: 500
# i inkrementieren: 440 -> 453 	 j: 456, floor term:12
# i: 453
# ----
# Länge zum Ende von Zeitpunkt i = 453: 484
# i inkrementieren: 453 -> 466 	 j: 469, floor term:12
# i: 466
# ----
# Länge zum Ende von Zeitpunkt i = 466: 506
# i inkrementieren: 466 -> 482 	 j: 487, floor term:15
# i: 482
# ----
# Länge zum Ende von Zeitpunkt i = 482: 499
# i inkrementieren: 482 -> 492 	 j: 494, floor term:9
# i: 492
# ----
# Länge zum Ende von Zeitpunkt i = 492: 340
# i inkrementieren: 492 -> 496 	 j: 497, floor term:3
# i: 496
# ----
# Länge zum Ende von Zeitpunkt i = 496: 500
# i inkrementieren: 496 -> 501 	 j: 502, floor term:4
# i: 501
# ----
# Länge zum Ende von Zeitpunkt i = 501: 499
# i inkrementieren: 501 -> 515 	 j: 519, floor term:13
# i: 515
# ----
# Länge zum Ende von Zeitpunkt i = 515: 489
# i inkrementieren: 515 -> 531 	 j: 535, floor term:15
# i: 531
# ----
# Länge zum Ende von Zeitpunkt i = 531: 503
# i inkrementieren: 531 -> 542 	 j: 545, floor term:10
# i: 542
# ----
# Länge zum Ende von Zeitpunkt i = 542: 480
# i inkrementieren: 542 -> 548 	 j: 549, floor term:5
# i: 548
# ----
# Länge zum Ende von Zeitpunkt i = 548: 504
# i inkrementieren: 548 -> 553 	 j: 554, floor term:4
# i: 553
# ----
# Länge zum Ende von Zeitpunkt i = 553: 305
# i inkrementieren: 553 -> 560 	 j: 562, floor term:6
# i: 560
# ----
# Länge zum Ende von Zeitpunkt i = 560: 399
# i inkrementieren: 560 -> 565 	 j: 566, floor term:4
# i: 565
# ----
# Länge zum Ende von Zeitpunkt i = 565: 20
# i inkrementieren: 565 -> 566 	 j: 566, floor term:0
# i: 566
# ----
# Länge zum Ende von Zeitpunkt i = 566: 0
# i inkrementieren: 566 -> 567 	 j: 566, floor term:0
# i: 567
# ----
# Länge zum Ende von Zeitpunkt i = 567: 348
# i inkrementieren: 567 -> 574 	 j: 576, floor term:6
# i: 574
# ----
# Länge zum Ende von Zeitpunkt i = 574: 496
# i inkrementieren: 574 -> 581 	 j: 582, floor term:6
# i: 581
# ----
# Länge zum Ende von Zeitpunkt i = 581: 446
# i inkrementieren: 581 -> 590 	 j: 592, floor term:8
# i: 590
# ----
# Länge zum Ende von Zeitpunkt i = 590: 510
# i inkrementieren: 590 -> 599 	 j: 601, floor term:8
# i: 599
# ----
# Länge zum Ende von Zeitpunkt i = 599: 494
# i inkrementieren: 599 -> 612 	 j: 615, floor term:12
# i: 612
# ----
# Länge zum Ende von Zeitpunkt i = 612: 457
# i inkrementieren: 612 -> 621 	 j: 623, floor term:8
# i: 621
# ----
# Länge zum Ende von Zeitpunkt i = 621: 221
# i inkrementieren: 621 -> 623 	 j: 623, floor term:1
# i: 623
# ----
# Länge zum Ende von Zeitpunkt i = 623: 496
# i inkrementieren: 623 -> 630 	 j: 632, floor term:6
# i: 630
# ----
# Länge zum Ende von Zeitpunkt i = 630: 491
# i inkrementieren: 630 -> 641 	 j: 644, floor term:10
# i: 641
# ----
# Länge zum Ende von Zeitpunkt i = 641: 470
# i inkrementieren: 641 -> 651 	 j: 654, floor term:9
# i: 651
# ----
# Länge zum Ende von Zeitpunkt i = 651: 445
# i inkrementieren: 651 -> 661 	 j: 663, floor term:9
# i: 661
# ----
# Länge zum Ende von Zeitpunkt i = 661: 498
# i inkrementieren: 661 -> 667 	 j: 668, floor term:5
# i: 667
# ----
# Länge zum Ende von Zeitpunkt i = 667: 468
# i inkrementieren: 667 -> 673 	 j: 674, floor term:5
# i: 673
# ----
# Länge zum Ende von Zeitpunkt i = 673: 326
# i inkrementieren: 673 -> 679 	 j: 680, floor term:5
# i: 679
# ----
# Länge zum Ende von Zeitpunkt i = 679: 512
# i inkrementieren: 679 -> 686 	 j: 688, floor term:6
# i: 686
# ----
# Länge zum Ende von Zeitpunkt i = 686: 502
# i inkrementieren: 686 -> 695 	 j: 697, floor term:8
# i: 695
# j == len(list) (vor else)
#
#
# -----------Datasets-------------
# Dataset({
#     features: ['input_ids', 'attention_mask'],
#     num_rows: 368
# })
# Dataset({
#     features: ['input_ids', 'attention_mask'],
#     num_rows: 79
# })

# %%
from transformers import AutoModelWithLMHead

# Setting the tokenizer and the model

tokenizer = AutoTokenizer.from_pretrained("dbmdz/german-gpt2")
tokenizer.pad_token = '<pad>'

model = AutoModelWithLMHead.from_pretrained("dbmdz/german-gpt2")
# Out:
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# loading configuration file config.json from cache at C:\Users\User/.cache\huggingface\hub\models--dbmdz--german-gpt2\snapshots\f0edef6d975b1338bae533502e1dae74974cb2d2\config.json
# Model config GPT2Config {
#   "_name_or_path": "dbmdz/german-gpt2",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.0,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.0,
#   "eos_token_id": 50256,
#   "gradient_checkpointing": false,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.0,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.25.1",
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading file vocab.json from cache at None
# loading file merges.txt from cache at None
# loading file tokenizer.json from cache at C:\Users\User/.cache\huggingface\hub\models--dbmdz--german-gpt2\snapshots\f0edef6d975b1338bae533502e1dae74974cb2d2\tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at C:\Users\User/.cache\huggingface\hub\models--dbmdz--german-gpt2\snapshots\f0edef6d975b1338bae533502e1dae74974cb2d2\config.json
# Model config GPT2Config {
#   "_name_or_path": "dbmdz/german-gpt2",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.0,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.0,
#   "eos_token_id": 50256,
#   "gradient_checkpointing": false,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.0,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.25.1",
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# C:\Users\User\Desktop\SoftwareProject\venv\lib\site-packages\transformers\models\auto\modeling_auto.py:1177: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# loading configuration file config.json from cache at C:\Users\User/.cache\huggingface\hub\models--dbmdz--german-gpt2\snapshots\f0edef6d975b1338bae533502e1dae74974cb2d2\config.json
# Model config GPT2Config {
#   "_name_or_path": "dbmdz/german-gpt2",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.0,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.0,
#   "eos_token_id": 50256,
#   "gradient_checkpointing": false,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.0,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.25.1",
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# loading weights file pytorch_model.bin from cache at C:\Users\User/.cache\huggingface\hub\models--dbmdz--german-gpt2\snapshots\f0edef6d975b1338bae533502e1dae74974cb2d2\pytorch_model.bin
# All model checkpoint weights were used when initializing GPT2LMHeadModel.
#
# All the weights of GPT2LMHeadModel were initialized from the model checkpoint at dbmdz/german-gpt2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use GPT2LMHeadModel for predictions without further training.

# %%
from transformers import DataCollatorForLanguageModeling
from transformers import TrainingArguments, Trainer

# Setting up the training procedure

training_args = TrainingArguments(output_dir="Theater_Model",
                                  report_to="none",
                                  overwrite_output_dir=True,
                                  per_device_train_batch_size=4,
                                  per_device_eval_batch_size=4,
                                  gradient_accumulation_steps=2,
                                  evaluation_strategy="steps",
                                  eval_steps=30,
                                  num_train_epochs=5,
                                  save_steps=90,
                                  logging_steps =30)

data_collator = DataCollatorForLanguageModeling(tokenizer, mlm=False)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset_train,
    eval_dataset=dataset_test,
    data_collator = data_collator
)
# Out:
# PyTorch: setting up devices

# %%
# Run the training loop
trainer.train()
# Out:
# C:\Users\User\Desktop\SoftwareProject\venv\lib\site-packages\transformers\optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 368
#   Num Epochs = 5
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 2
#   Total optimization steps = 230
#   Number of trainable parameters = 124445952
# You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='230' max='230' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [230/230 05:16, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>30</td>
#       <td>4.300600</td>
#       <td>4.568961</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>3.953800</td>
#       <td>4.452933</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>3.768800</td>
#       <td>4.406631</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>3.659600</td>
#       <td>4.390954</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>3.594700</td>
#       <td>4.390180</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>3.531200</td>
#       <td>4.384194</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>3.491000</td>
#       <td>4.387879</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 79
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 79
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 79
#   Batch size = 4
# Saving model checkpoint to Theater_Model\checkpoint-90
# Configuration saved in Theater_Model\checkpoint-90\config.json
# Model weights saved in Theater_Model\checkpoint-90\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 79
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 79
#   Batch size = 4
# ***** Running Evaluation *****
#   Num examples = 79
#   Batch size = 4
# Saving model checkpoint to Theater_Model\checkpoint-180
# Configuration saved in Theater_Model\checkpoint-180\config.json
# Model weights saved in Theater_Model\checkpoint-180\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 79
#   Batch size = 4
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=230, training_loss=3.7321149743121604, metrics={'train_runtime': 320.9332, 'train_samples_per_second': 5.733, 'train_steps_per_second': 0.717, 'total_flos': 470307285504000.0, 'train_loss': 3.7321149743121604, 'epoch': 5.0})

# %%
# Save the final version of the model
trainer.save_model("Theater-Model-final")
# Out:
# Saving model checkpoint to Theater-Model-final
# Configuration saved in Theater-Model-final\config.json
# Model weights saved in Theater-Model-final\pytorch_model.bin
